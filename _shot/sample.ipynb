# %% [markdown]
# # Revenue analysis
#
# A quick look at quarterly performance across regions.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "region": ["UK", "India", "Singapore"],
    "revenue": [128, 174, 96],
})
print("loaded", len(df), "rows")
# Out:
# loaded 3 rows

# %%
df
# Out:
#     region  revenue
# 0         UK      128
# 1      India      174
# 2  Singapore       96

# %%
df.plot(x="region", y="revenue", kind="bar")
